# %%
import torch
import numpy as np
from torchvision import transforms, datasets, models, transforms
from torch.utils.data import DataLoader
from torch import nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib  inline
import random
from tqdm import tqdm
import os
import pandas as pd
from PIL import Image
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display in google colab


from google.colab import drive
drive.mount('/content/drive')

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# !pip install torchinfo

# setting seed
torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

# !pip install -U nltk
import nltk
nltk.download('wordnet')

# !pip install torchinfo
# Out:
# Mounted at /content/drive
# Collecting torchinfo
#   Downloading https://files.pythonhosted.org/packages/00/ac/a33b67c628df213260fb0c39590dc68291382d1f66bfb159e4af27f25ca7/torchinfo-0.1.1-py3-none-any.whl
# Installing collected packages: torchinfo
# Successfully installed torchinfo-0.1.1
# Collecting nltk
#   Downloading https://files.pythonhosted.org/packages/5e/37/9532ddd4b1bbb619333d5708aaad9bf1742f051a664c3c6fa6632a105fd8/nltk-3.6.2-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 8.6MB/s
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.0.1)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.41.1)
# Requirement already satisfied, skipping upgrade: regex in /usr/local/lib/python3.7/dist-packages (from nltk) (2019.12.20)
# Installing collected packages: nltk
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed nltk-3.6.2
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.7/dist-packages (0.1.1)

# %% [markdown]
# Normalizing caption text and arranging train, val and test captions

# %%
image_folder_path = "/content/drive/MyDrive/VR final project/Flickr8K/Flicker8k_Images/"
image_text_folder_path = "/content/drive/MyDrive/VR final project/Flickr8K/Flickr8k_text/"

import re
import string
def normalize_text(text):
  text = text.lower()

  # Remove punctuations
  exclude = set(string.punctuation)
  text = "".join(ch for ch in text if ch not in exclude)

  
  regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
  text = re.sub(regex, " ", text)

  # Remove extra white space
  text = " ".join(text.split())
  return text


def sep_image_name(x):
  y = str(x)
  return y[:-2]

def create_label_set(filename_lst, file_to_token_dict):
  label_lst = []
  for file in filename_lst:
    lst = file_to_token_dict[file]
    transformed_lst = []
    for i, sentence in enumerate(lst):
      transformed_lst.append("<sos> " + normalize_text(sentence) + " <eos>")
    label_lst.append(transformed_lst)
  return label_lst 

def create_table(image_folder_path, image_text_folder_path, token_type='Lemmatised'):
  # image and raw token caption
  image_rawToken_caption = pd.read_csv(os.path.join(image_text_folder_path, 'Flickr8k.token.txt'), sep="\t", header = None, names = ["image", "caption"])
  # image and lemmatized token caption
  image_lemmatize_caption = pd.read_csv(os.path.join(image_text_folder_path, 'Flickr8k.lemma.token.txt'), sep="\t", header = None, names = ["image", "caption"])

  train_image_list = pd.read_csv(os.path.join(image_text_folder_path, 'Flickr_8k.trainImages.txt'), sep='\t', header=None, names=['image'])
  val_image_list = pd.read_csv(os.path.join(image_text_folder_path, 'Flickr_8k.valImages.txt'), sep='\t', header=None, names=['image'])
  test_image_list = pd.read_csv(os.path.join(image_text_folder_path, 'Flickr_8k.testImages.txt'), sep='\t', header=None, names=['image'])

  image_rawToken_caption['imageName'] = image_rawToken_caption['image'].apply(sep_image_name)
  image_with_rawTokens = image_rawToken_caption.groupby('imageName')['caption'].agg(list)
  image_filename_to_rawtaglst = image_with_rawTokens.to_dict()

  image_lemmatize_caption['imageName'] = image_lemmatize_caption['image'].apply(sep_image_name)
  image_with_lemmTokens = image_lemmatize_caption.groupby('imageName')['caption'].agg(list)
  image_filename_to_lemmtaglst = image_with_lemmTokens.to_dict()

  train_item_lst = train_image_list['image'].to_list()
  val_item_lst = val_image_list['image'].to_list()
  test_item_lst = test_image_list['image'].to_list()

  if (token_type == 'Lemmatised'):
    train_tags_lst = create_label_set(train_item_lst, image_filename_to_lemmtaglst)
    val_tags_lst = create_label_set(val_item_lst, image_filename_to_lemmtaglst)
    test_tags_lst = create_label_set(test_item_lst, image_filename_to_lemmtaglst)
  else :
    train_tags_lst = create_label_set(train_item_lst, image_filename_to_rawtaglst)
    val_tags_lst = create_label_set(val_item_lst, image_filename_to_rawtaglst)
    test_tags_lst = create_label_set(test_item_lst, image_filename_to_rawtaglst)

  return train_tags_lst, val_tags_lst, test_tags_lst


lst_labels = create_table(image_folder_path, image_text_folder_path, token_type='non-Lemmatised')
#lst_labels[0] -> train labels
# lst_labels[1] -> val labels
# lst_labels[2] -> test labels

# %% [markdown]
# Loading the train, validation and test tensor that was preprocessed and saved in drive

# %%
# !cp -r  /content/drive/MyDrive/VR" "final" "project/TrainLoader.pth /content/
# !cp -r /content/drive/MyDrive/VR" "final" "project/TestLoader.pth /content/
# !cp -r /content/drive/MyDrive/VR" "final" "project/ValLoader.pth  /content/

# %%
TrainLoader = torch.load('TrainLoader.pth')

# %%
ValLoader = torch.load('ValLoader.pth')

# %%
TestLoader = torch.load('TestLoader.pth')

# %% [markdown]
# Creating Vocabulary from the given captions

# %%
# preparing data for LSTM

import itertools

class Vocab():
  def __init__(self):
    self.word_to_index = {}
    self.index_to_word = {}
    self.n_words = 0
    self.word_set = {}

  def buildVocab(self, label_lst):
    label_lst = list(itertools.chain.from_iterable(label_lst[0])) # building vocab from train data
    big_str = " ".join(label_lst)
    big_str = big_str.lower() # lower case
    self.word_set = set(big_str.split(" "))
    self.word_set.add("<UNK>")
    self.word_set.add("<PAD>")
    self.word_to_index = {word:index for index, word in enumerate(self.word_set)}
    self.index_to_word = {index:word for index, word in enumerate(self.word_set)}
    self.n_words = len(self.word_set)

  def transformLabelToToken(self, label_lst):
    transformed_lst = []
    for lst in label_lst:
      new_lst = []
      for lst_of_sent in lst:
        new_lst_of_sent = []
        for sentence in lst_of_sent:
          normalize_text(sentence)
          transformed_sent = list(map(lambda x: self.word_to_index[x] if x in self.word_to_index else self.word_to_index["<UNK>"], sentence.lower().split(" ")))
          new_lst_of_sent.append(transformed_sent)
        new_lst.append(new_lst_of_sent)
      transformed_lst.append(new_lst)
    return transformed_lst  

  def padTokens(self, token_lst, MAX_LEN):
    for i in range(len(token_lst)):
      for j in range(len(token_lst[i])):
        for k in range(len(token_lst[i][j])):
          if (len(token_lst[i][j][k]) < MAX_LEN):
            for x in range(MAX_LEN - len(token_lst[i][j][k])):
              token_lst[i][j][k].append(self.word_to_index["<PAD>"])

    return token_lst

# %%
vggNet = models.vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))

# %%
resnet = models.resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))

# %% [markdown]
# Model architecture code

# %%
class EncoderCNN(nn.Module):
  def __init__(self, pretrained_model):
    """
    Using pretrained CNN architecture - try using VGGnet as given in the paper: 
    Fine tuning on the upper layers also possible - try if there is time
    """
    super(EncoderCNN, self).__init__()

    model_layers = list(pretrained_model.children())[:-2] 
    self.pretrained_model = nn.Sequential(*model_layers)

    # fine-tuning is also possible 
    for param in self.pretrained_model.parameters():
      param.requires_grad = False    

  def forward(self, img_input):
    output = self.pretrained_model(img_input)  # (batch_size, img_depth, img_height, img_width)
    output = output.permute(0, 2, 3, 1).contiguous()  #(batch_size, img_height, img_width, img_depth)
    return output


class DecoderRNN(nn.Module):
  def __init__(self, embed_size, vocab_size, encoder_size, hidden_size, dropout_prob):  
    """
    embed_size : embedding size (output of embedding layer)
    vocab_size: size of vocabulary
    encoder_size: size of encoder output feature i.e image_depth 
    decoder_size: size of decoder hidden feature i.e hidden size of lstm
    """
    super(DecoderRNN, self).__init__()
    self.embed_size = embed_size
    self.vocab_size = vocab_size
    self.encoder_size = encoder_size
    self.hidden_size = hidden_size  
    
    self.embedding = nn.Embedding(vocab_size, embed_size)
    
    # lstm_cell. For multilayers, define multiple such 
    self.lstm_cell = nn.LSTMCell(embed_size, hidden_size, bias=True)

    self.dropout = nn.Dropout(p = dropout_prob)
    self.linear = nn.Linear(hidden_size, vocab_size)  # final layer to give logits on vocabulary

    self.init_h = nn.Linear(encoder_size, hidden_size) # initialization of initial hidden state vector
    self.init_c = nn.Linear(encoder_size, hidden_size) # initialization of initial cell state vector


  def init_hidden(self, encoder_out):
    mean_encoder_out = encoder_out.mean(dim=1) # (batch_size, num_pixels, encoder_size) -> (batch_size, encoder_size)
    init_hidden_state = self.init_h(mean_encoder_out)
    init_cell_state = self.init_c(mean_encoder_out)
    return init_hidden_state, init_cell_state

  def forward(self, encoder_out, captions, MAX_LEN):
    """
    Uses teacher forcing technique
    """
    # encoder_out shape: (batch_size, image_height, image_width, image_depth)
    batch_size = encoder_out.size(0)
    encoder_size = encoder_out.size(-1)
    encoder_out = encoder_out.view(batch_size, -1, encoder_size) # now the shape: (batch_size, num_pixels, encoder_size)
    
    
    embeddings = self.embedding(captions[:, :-1])      # embeddings shape: (batch_size, seq_len->MAX_LEN-1, embed_size)
    hidden_state, cell_state = self.init_hidden(encoder_out)   # hidden_state shape: (batch_size, hidden_size)

    out_logits = torch.zeros(batch_size, MAX_LEN-1, self.vocab_size).to(device)   # (batch_size, seq_len->MAX_LEN-1, vocab_size)

    for t in range(MAX_LEN-1):
      hidden_state, cell_state = self.lstm_cell(embeddings[:, t, :], (hidden_state, cell_state))
      output= self.linear(self.dropout(hidden_state))
      out_logits[:, t, :] = output

    return out_logits


  def mix_technique(self, encoder_out, captions, MAX_LEN):
    """
    Uses teacher_forcing for the first 10 time steps and then onwards non-teacher forcing
    """

    batch_size = encoder_out.size(0)
    encoder_size = encoder_out.size(-1)
    encoder_out = encoder_out.view(batch_size, -1, encoder_size) # now the shape: (batch_size, num_pixels, encoder_size)
    

    embeddings = self.embedding(captions[:, :, -1]) 
    hidden_state, cell_state = self.init_hidden(encoder_out)

    out_logits = torch.zeros(batch_size, MAX_LEN-1, self.vocab_size).to(device)

    for t in range(MAX_LEN-1):
      if (t<10): # change t for controlling number of steps in teacher-forcing
        input = embeddings[:, t, :]
      else:
        input = prev_embedding
      hidden_state, cell_state = self.lstm_cell(input, (hidden_state, cell_state))
      output = self.linear(self.dropout(hidden_state))
      out_logits[:, t, :] = output
      output = nn.LogSoftmax(dim=1)(output)
      output = output.argmax(1)  # output shape: (batch_size)
      prev_embedding = self.embedding(output.unsqueeze(1))  # no teacher forcing
    
    return out_logits
    

  def generateCaptions(self, encoder_out, VocabObj, MAX_LEN):
    """
    Doesn't use teacher forcing technique -> used while decoding and testing
    Used for batch_size = 1
    """
    batch_size = encoder_out.size(0)
    encoder_size = encoder_out.size(-1)
    encoder_out = encoder_out.view(batch_size, -1, encoder_size)

    # embedding for '<sos>'
    sos_tensor = VocabObj.word_to_index["<sos>"]
    sos_tensor = torch.tensor([[sos_tensor] for l in range(batch_size)], dtype=int)  # sos_tensor shape: (batch_size, 1)
    sos_tensor = sos_tensor.to(device)
    embedding = self.embedding(sos_tensor) # initial input embedding

    hidden_state, cell_state = self.init_hidden(encoder_out)

    out_logits = torch.zeros(batch_size, MAX_LEN-1, self.vocab_size).to(device)
    
    generated_captions = ["<sos>"]

    with torch.no_grad():
      for t in range(MAX_LEN-1):
        hidden_state, cell_state = self.lstm_cell(embedding.squeeze(1), (hidden_state, cell_state))
        output= self.linear(hidden_state)  # output shape: (batch_size, vocab_size)
        out_logits[:, t, :] = output
        output = nn.LogSoftmax(dim=1)(output)
        output = output.argmax(1)  # output shape: (batch_size)
        embedding = self.embedding(output.unsqueeze(1))  # no teacher forcing

        generated_captions.append(VocabObj.index_to_word[output.item()])
        if (VocabObj.index_to_word[output.item()] == "<eos>"):
          break

    #print(f"output: {output}") 
    return generated_captions


class ImageCaptionModel(nn.Module):
  def __init__(self, pretrained_model, embed_size, vocab_size, encoder_size, hidden_size, dropout_prob):
    super(ImageCaptionModel, self).__init__()
    self.encoder = EncoderCNN(pretrained_model)
    self.decoder = DecoderRNN(embed_size, vocab_size, encoder_size, hidden_size, dropout_prob)
  
  def forward(self, img_input, captions, MAX_LEN):  # remove arg MAX_LEN while summary
    return self.decoder(self.encoder(img_input), captions, MAX_LEN) # put MAX_LEN = 163 while summary

  def mix_technique(self, img_input, captions, MAX_LEN):
    return self.decoder(self.encoder(img_input), captions, MAX_LEN)

  def generateCaptions(self, img_input, VocabObj, MAX_LEN):
    return self.decoder.generateCaptions(self.encoder(img_input), VocabObj, MAX_LEN)

# %% [markdown]
# Visualizing model summary and memory details

# %%
# EMBED_SIZE = 256 
# ENCODER_SIZE = 512  
# HIDDEN_SIZE = 512  
# VOCAB_SIZE = 7631
# LSTM_DROPOUT_PROB = 0.5 
# NUM_EPOCHS = 20 
# LEARNING_RATE = 5e-4  
# model = ImageCaptionModel(resnet, EMBED_SIZE, VOCAB_SIZE, ENCODER_SIZE, HIDDEN_SIZE, LSTM_DROPOUT_PROB)
# model = model.to(device)

# from torchinfo import summary

# summary(model, [(32, 3, 256, 256), (32, 163)], dtypes=[torch.float, torch.int])

# %% [markdown]
# Training function

# %%
def train(model, TrainLoader, TrainCaptionLoader, ValLoader, ValCaptionLoader, num_epochs, learning_rate, VocabObj, MAX_LEN, teacher_forcing=True):
  model = model.to(device)
  criterion = nn.CrossEntropyLoss(ignore_index = VocabObj.word_to_index["<PAD>"])
  optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

  train_loss_lst = []
  val_loss_lst = []

  for epoch in range(num_epochs):
    model.train()
    caption_loader = iter(TrainCaptionLoader)
    train_loss = 0
    for idx, img in tqdm(enumerate(TrainLoader), total=len(TrainLoader), position=0, leave=True):
      img = img.to(device)
      caption = next(caption_loader)
      caption = caption.to(device)

      batch_size = img.size(0)
      if (teacher_forcing):
        output_logits = model(img, caption, MAX_LEN)
      else:
        output_logits = model.mix_technique(img, caption, MAX_LEN)

      optimizer.zero_grad()
      loss = criterion(output_logits.permute(0, 2, 1).contiguous(), caption[:, 1:])
      loss.backward()
      optimizer.step()

    train_loss_lst.append(loss/batch_size)

    # validation loop, if training is taking too much time replace epoch==num_epochs-1 otherwise epoch <= num_epochs-1
    if (epoch == num_epochs-1): 
      model.eval()
      with torch.no_grad():
        val_caption_loader = iter(ValCaptionLoader)
        val_loss = float('inf')
        for idx, val_img in tqdm(enumerate(ValLoader), total=len(ValLoader), position=0, leave=True):
          val_img = val_img.to(device)
          batch_size = val_img.size(0)
          val_caption = next(val_caption_loader)
          for y in range(5):  
            val_cap = val_caption[y].to(device)
            val_cap = val_cap.unsqueeze(0)

            if (teacher_forcing):
              val_out_logits = model(val_img, val_cap, MAX_LEN)
            else:
              val_out_logits = model.mix_technique(val_img, val_cap, MAX_LEN)

            tmp_val_loss = criterion(val_out_logits.permute(0, 2, 1).contiguous(), val_cap[:, 1:])

            val_loss = min(val_loss, tmp_val_loss)

        val_loss_lst.append(val_loss/batch_size) 
    else:
      val_loss_lst.append(torch.zeros(1))

    print(f"Epoch: {epoch+1}/{num_epochs}, train loss: {train_loss_lst[epoch].item(): .4f}, validation loss: {val_loss_lst[epoch].item(): .4f}")

  return train_loss_lst, val_loss_lst


def showPlot(train_loss_lst, val_loss_lst):
  plt.figure(figsize=(8, 8))
  plt.plot(train_loss_lst)
  plt.plot(val_loss_lst)
  plt.title('loss per epoch')
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['Training loss', 'Validation loss'])
  plt.savefig('Plot_of_loss_per_epoch.jpg')

# %% [markdown]
# Evaluation function

# %%
# outputing captions -> Greedy method
def outputCaptions(model, Loader, VocabObj, MAX_LEN):
  # Loader can be ValLoader or TestLoader (batch_size is assumed to be 1 in this case)
  model.eval()
  output_captions = []
  with torch.no_grad():
    for idx, img in enumerate(Loader):
      img = img.to(device)
      caption_out = model.generateCaptions(img, VocabObj, MAX_LEN)
      output_captions.append(" ".join(caption_out))
  return output_captions


# BLEU eval metric
from nltk.translate.bleu_score import corpus_bleu, sentence_bleu
from nltk.translate.meteor_score import meteor_score
def BLEU(reference_doc, sentence_list):
  # reference_doc 3-dm list
  # sentence_list is list of lists of sentence tokens 2-dm list
  bleuScore1 = corpus_bleu(reference_doc, sentence_list, weights=(1, 0, 0, 0))
  bleuScore2 = corpus_bleu(reference_doc, sentence_list, weights=(0.5, 0.5, 0, 0))
  bleuScore3 = corpus_bleu(reference_doc, sentence_list, weights=(1/3, 1/3, 1/3, 0))
  bleuScore4 = corpus_bleu(reference_doc, sentence_list, weights=(0.25, 0.25, 0.25, 0.25))
  return bleuScore1, bleuScore2, bleuScore3, bleuScore4


# Not a correct implementation of METEOR score; True one is more complex
def METEOR(reference_doc, sentence_list):
  score = 0
  for idx, _ in enumerate(sentence_list):
    score += meteor_score(reference_doc[idx], sentence_list[idx])
  return score/len(sentence_list) # averaging METEOR score

def Eval_score(label_lst, predicted_list):
  # label_lst -> list of lists of 5 sentences esp label_lst[2] #test
  sentence_list = [sent.split(" ") for sent in predicted_list]
  reference_doc = [[k.split(" ") for k in l] for l in label_lst] 
  bleuScore1, bleuScore2, bleuScore3, bleuScore4 = BLEU(reference_doc, sentence_list)
  meteorScore = METEOR(label_lst, predicted_list)
  print(f"BLEU-1 score: {bleuScore1: .5f}, BLEU-2 score: {bleuScore2: .5f}, BLEU-3 score: {bleuScore3: .5f}, BLEU-4 score: {bleuScore4: .5f}\nAverage METEOR score: {meteorScore: .5f}\n")



# evaluation
def evalResults(validation_captions, test_captions, label_lst):
  val_ref = label_lst[1]
  test_ref = label_lst[2]

  print(f"Validation metrics:\n")
  Eval_score(val_ref, validation_captions)

  print(f"\n Test metrics:\n")
  Eval_score(test_ref, test_captions)

# %%
# script

BATCH_SIZE = 32 
MAX_LEN = 163 
VocabObj = Vocab()
VocabObj.buildVocab(lst_labels)
token_lst = VocabObj.transformLabelToToken(lst_labels)
token_lst = VocabObj.padTokens(token_lst, MAX_LEN)

def prepareImageLoader(Loader, batch_size):
  lst = []
  for idx, img in enumerate(Loader):
    lst.append(img.squeeze(0)) 

  return DataLoader(dataset=lst, batch_size = batch_size, pin_memory=True)

# %%
TrainLoader = prepareImageLoader(TrainLoader, BATCH_SIZE)

# %%
def take_first_caption(token_lst):
  lst_tokens = []
  for lst in token_lst:
    lst_tokens.append(torch.tensor(lst[0]))
  return lst_tokens

def take_all_captions(token_lst):
  lst_tokens = []
  for lst in token_lst:
    for x in lst:
      lst_tokens.append(torch.tensor(x))
  return lst_tokens

TrainCaptionLoader = DataLoader(dataset = take_first_caption(token_lst[0]), batch_size = BATCH_SIZE)
ValCaptionLoader = DataLoader(dataset = take_all_captions(token_lst[1]), batch_size = 5)




EMBED_SIZE = 256 
ENCODER_SIZE = 512  
HIDDEN_SIZE = 512   
VOCAB_SIZE = VocabObj.n_words
LSTM_DROPOUT_PROB = 0.5 
NUM_EPOCHS = 20 
LEARNING_RATE = 5e-4  

model = ImageCaptionModel(vggNet, EMBED_SIZE, VOCAB_SIZE, ENCODER_SIZE, HIDDEN_SIZE, LSTM_DROPOUT_PROB)
model = model.to(device)

# %%
train_loss_lst, val_loss_lst = train(model, TrainLoader, TrainCaptionLoader, ValLoader, ValCaptionLoader, NUM_EPOCHS, LEARNING_RATE, VocabObj, MAX_LEN, teacher_forcing=False)
# Out:
# 100%|██████████| 188/188 [02:00<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 1/20, train loss:  0.3212, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 2/20, train loss:  0.2873, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 3/20, train loss:  0.2623, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 4/20, train loss:  0.2322, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 5/20, train loss:  0.2150, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 6/20, train loss:  0.1999, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 7/20, train loss:  0.1796, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 8/20, train loss:  0.1563, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 9/20, train loss:  0.1437, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 10/20, train loss:  0.1303, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 11/20, train loss:  0.1208, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 12/20, train loss:  0.1096, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 13/20, train loss:  0.1000, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 14/20, train loss:  0.0849, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 15/20, train loss:  0.0870, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 16/20, train loss:  0.0768, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 17/20, train loss:  0.0723, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 18/20, train loss:  0.0606, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
#   0%|          | 0/188 [00:00<?, ?it/s]
# Epoch: 19/20, train loss:  0.0547, validation loss:  0.0000
# 100%|██████████| 188/188 [01:59<00:00,  1.57it/s]
# 100%|██████████| 1000/1000 [03:03<00:00,  5.46it/s]
# Epoch: 20/20, train loss:  0.0542, validation loss:  0.6222

# %%
showPlot(train_loss_lst, val_loss_lst) # omitted since we validating only at the end of training

# %%
validation_captions = outputCaptions(model, ValLoader, VocabObj, MAX_LEN)
test_captions = outputCaptions(model, TestLoader, VocabObj, MAX_LEN)

# %%
validation_captions
# Out:
# ['<sos> boy in black shirt is sitting on bench with his arms crossed <eos>',
#  '<sos> boy in red shirt is standing on rock next to building <eos>',
#  '<sos> boy holds ball while another dog looks at it <eos>',
#  '<sos> black dog is jumping over log in air <eos>',
#  '<sos> man in red shorts is climbing rock face <eos>',
#  '<sos> child in bathtub with water coming out of water <eos>',
#  '<sos> group of people are walking in front of bridge in city <eos>',
#  '<sos> boy and girl are playing in field <eos>',
#  '<sos> boy in red shirt is standing on top of cliff in front of building <eos>',
#  '<sos> man in red jacket and hat sits on bench <eos>',
#  '<sos> man in black wetsuit is surfing <eos>',
#  '<sos> baseball player hitting ball <eos>',
#  '<sos> black dog in water <eos>',
#  '<sos> boy in red shirt is jumping into pool <eos>',
#  '<sos> man is standing on top of cliff taking picture of people <eos>',
#  '<sos> boy in swimsuit is jumping into pool <eos>',
#  '<sos> man in blue shirt is smiling with his arms crossed <eos>',
#  '<sos> black and white dog is swimming through water <eos>',
#  '<sos> man in red jacket is climbing rock face <eos>',
#  '<sos> woman in black and white shirt is smiling with woman in blue shirt <eos>',
#  '<sos> brown dog is running through woods <eos>',
#  '<sos> closeup of man wearing black hat <eos>',
#  '<sos> black and white dog is jumping up to catch green frisbee <eos>',
#  '<sos> group of people are standing together on brick wall <eos>',
#  '<sos> girl in black dress is standing next to man in black jacket <eos>',
#  '<sos> black dog is running through grass <eos>',
#  '<sos> boy in red shirt and white shorts is playing with ball <eos>',
#  '<sos> dog is jumping into swimming pool <eos>',
#  '<sos> girl in black dress is running in field of flowers <eos>',
#  '<sos> dog is chewing on bone with its mouth open <eos>',
#  '<sos> man in black shirt is looking down at many woman in black shirt <eos>',
#  '<sos> girl in black dress is sitting on bench next to girl in black jacket <eos>',
#  '<sos> girl in swimsuit is standing in front of water on beach <eos>',
#  '<sos> black and white dog is jumping up at another dog who is wearing blue shirt <eos>',
#  '<sos> black and white dog is running on sand <eos>',
#  '<sos> woman in black and white shirt is smiling with woman in black and white checkered outfit <eos>',
#  '<sos> boy is doing trick on skateboard in front of building with crowd of people <eos>',
#  '<sos> man in red jacket is sitting on rock next to waterfall <eos>',
#  '<sos> boy in red shirt is playing with blue ball <eos>',
#  '<sos> boy in red shirt jumps into air while another boy watches <eos>',
#  '<sos> boy in blue shirt is looking at camera in front of another man who is sitting on rock wall <eos>',
#  '<sos> biker rides unicycle <eos>',
#  '<sos> boy and girl playing cricket <eos>',
#  '<sos> black dog is swimming through water <eos>',
#  '<sos> group of people are walking on desert <eos>',
#  '<sos> girl in pink shirt is standing in front of reception desk <eos>',
#  '<sos> child in green shirt is playing with tennis ball in front of her arms <eos>',
#  '<sos> brown dog is running on beach <eos>',
#  '<sos> dog runs through field of dry grass <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> brown dog is running through field <eos>',
#  '<sos> boy in black jacket is smiling with his arms crossed in front of another man who is taking photo <eos>',
#  '<sos> man in black shirt is about to get ball while another dog watches <eos>',
#  '<sos> man in red shirt climbs rock climbing in front of waterfall <eos>',
#  '<sos> boy in blue shirt is looking at camera <eos>',
#  '<sos> boy is wading through water while another boy watches <eos>',
#  '<sos> boy in red jacket is jumping on snowboard in snow <eos>',
#  '<sos> man is climbing up mountain <eos>',
#  '<sos> girl in pink shirt is standing in front of reception desk <eos>',
#  '<sos> man in white shirt is sitting on bench next to building with his arms crossed <eos>',
#  '<sos> dog is jumping into swimming pool <eos>',
#  '<sos> boy in blue shirt is sitting on bench next to building <eos>',
#  '<sos> man in red coat and black pants sits next to man in black jacket and red cap <eos>',
#  '<sos> bicyclist is doing trick in midair <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> biker riding bike through forest <eos>',
#  '<sos> brown and white dog is jumping up to catch ball <eos>',
#  '<sos> group of people are standing on top of one person in black shirt <eos>',
#  '<sos> man in black shirt is looking at pad of woman in black shirt <eos>',
#  '<sos> girl in pink shirt is blowing bubbles with her arms crossed <eos>',
#  '<sos> man in blue shirt is riding bike down paved road <eos>',
#  '<sos> two brown dogs are running on snow <eos>',
#  '<sos> man in flannel suit is jumping up to his skateboard <eos>',
#  '<sos> boy in blue shirt is running on grass <eos>',
#  '<sos> man in black jacket is surfing on rock <eos>',
#  '<sos> group of people are standing in front of lake <eos>',
#  '<sos> boy in blue uniform kicks soccer ball while another player in blue and white uniform looks on <eos>',
#  '<sos> group of people are riding on roller coaster <eos>',
#  '<sos> black and white dog is running with brown dog in front of white building <eos>',
#  '<sos> black dog is jumping over hurdle <eos>',
#  '<sos> black dog is jumping in air to catch disc <eos>',
#  '<sos> black and white dog is standing on pavement with black and white dog <eos>',
#  '<sos> group of people are walking through snow <eos>',
#  '<sos> man in black wetsuit is surfing on beach <eos>',
#  '<sos> person in yellow shirt is riding on bike <eos>',
#  '<sos> brown dog is running through field <eos>',
#  '<sos> brown dog is swimming through water <eos>',
#  '<sos> black and white dog is jumping over hurdle <eos>',
#  '<sos> black and white dog is walking on snow covered hill <eos>',
#  '<sos> boy in orange shirt is jumping into water with his arms spread wide <eos>',
#  '<sos> man and woman are standing on desert <eos>',
#  '<sos> man in black jacket and leather jacket is smiling with his arms crossed <eos>',
#  '<sos> man in black shirt is sitting on bench with graffiti on wall <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> girl in pink shirt is running on grass with metal object in background <eos>',
#  '<sos> woman in black is sitting on bench in front of window <eos>',
#  '<sos> boy in blue shorts is standing in front of large body of water <eos>',
#  '<sos> brown dog is jumping over hurdle <eos>',
#  '<sos> girl in black and brown dog is playing with ball in snow <eos>',
#  '<sos> group of people are standing in front of fence <eos>',
#  '<sos> baseball player crouching to make shot while another player in white uniform <eos>',
#  '<sos> man is doing trick on skateboard <eos>',
#  '<sos> boy in red shirt is jumping on skateboard in front of brick wall <eos>',
#  '<sos> black dog is swimming through water <eos>',
#  '<sos> man in black jacket is sitting on bench in front of house <eos>',
#  '<sos> girl in green shirt sitting on wooden floor surrounded by toys and smiles <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> child in red jacket is playing with red guitar <eos>',
#  '<sos> man in black jacket is smiling <eos>',
#  '<sos> black and white dog is running in grass <eos>',
#  '<sos> boy flips out of pool <eos>',
#  '<sos> boy hanging from jungle gym <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> boy in green shirt is jumping over hurdle in air <eos>',
#  '<sos> couple people are standing on shore next to water <eos>',
#  '<sos> lone skier in black pants is walking through snow covered hill <eos>',
#  '<sos> brown dog is standing in water <eos>',
#  '<sos> boy in red shirt is about to get ball while being blocked by him <eos>',
#  '<sos> brown dog is running through snow <eos>',
#  '<sos> boy in blue shirt is sitting on bench in front of building <eos>',
#  '<sos> man in black shirt is riding his bike on paved road <eos>',
#  '<sos> boy in red shirt is standing on sidewalk in front of building <eos>',
#  '<sos> man in black shirt is sitting in chair next to modern art structure <eos>',
#  '<sos> man and woman are smiling while sitting on carpeted staircase <eos>',
#  '<sos> girl in black shirt is sitting on bench with her arms crossed <eos>',
#  '<sos> crane wings outstreached above water <eos>',
#  '<sos> brown and white dog is jumping up to catch green ball <eos>',
#  '<sos> girl in black dress is standing next to man in black shirt <eos>',
#  '<sos> boy in red shirt is jumping on trampoline in front of large rock <eos>',
#  '<sos> dog is running through field <eos>',
#  '<sos> boy in blue shirt is jumping into air with arms spread <eos>',
#  '<sos> boy in blue shirt is jumping into air with arms spread <eos>',
#  '<sos> boy in red uniform chasing soccer ball <eos>',
#  '<sos> man and woman in black pose for picture <eos>',
#  '<sos> boy is standing on top of steps in front of building <eos>',
#  '<sos> boy in blue shirt and jeans is riding bike on paved road <eos>',
#  '<sos> group of people are standing in front of some stores <eos>',
#  '<sos> man in black wetsuit is surfing <eos>',
#  '<sos> boy in green shirt is sitting on bench in front of blue wall <eos>',
#  '<sos> boy in red shirt is sitting on bench next to building <eos>',
#  '<sos> brown and white dog is running through water <eos>',
#  '<sos> boy in red jacket is holding up to his mouth open <eos>',
#  '<sos> man in blue shirt is about to hit tennis ball with his arms crossed <eos>',
#  '<sos> boy in blue jersey is about to pitch basketball court <eos>',
#  '<sos> black dog and brown dog are biting each other dog <eos>',
#  '<sos> football player in red is challenging player in white uniform <eos>',
#  '<sos> man and woman are sitting on bench near water <eos>',
#  '<sos> boy in red shirt is jumping into air with his arms out in background <eos>',
#  '<sos> skier is standing on snowy mountain <eos>',
#  '<sos> girl in black dress is smiling whilst woman in blue jeans and blue jeans stands with her arms folded <eos>',
#  '<sos> man in brown shirt is jumping over hurdle <eos>',
#  '<sos> girl in black dress is smiling while woman in headscarf looks on <eos>',
#  '<sos> dog is jumping up at another dog who is wearing blue shirt <eos>',
#  '<sos> girl in black shirt is standing next to man in black shirt and blue cap <eos>',
#  '<sos> lone skier in red jacket is climbing rock face <eos>',
#  '<sos> baby in blue shirt is looking at camera <eos>',
#  '<sos> boy in red shirt is looking down at large brown dog with blue collar in background <eos>',
#  '<sos> child in red shirt is about to get ball while playing in yard <eos>',
#  '<sos> boy in red shirt climbs rock wall <eos>',
#  '<sos> brown dog is running though green grass <eos>',
#  '<sos> man in snow is snowboarding <eos>',
#  '<sos> man in black shirt is airborne <eos>',
#  '<sos> man in black shirt is standing next to man in black shirt and blue cap <eos>',
#  '<sos> child in red helmet is riding on pavement <eos>',
#  '<sos> black and white dog is biting ear of brown dog <eos>',
#  '<sos> group of people are playing in pool <eos>',
#  '<sos> boy is jumping on skateboard in front of wall <eos>',
#  '<sos> group of people walking down street <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> group of girls are playing in sparsely decorated kitchen <eos>',
#  '<sos> girl in pink dress is standing in front of reception desk <eos>',
#  '<sos> boy in red shirt is jumping on trampoline while another man watches <eos>',
#  '<sos> group of men play soccer <eos>',
#  '<sos> dog is running on grass <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> boy in fancy living room with his arms crossed <eos>',
#  '<sos> boy hits ball during game <eos>',
#  '<sos> man in blue shirt is splashing in water <eos>',
#  '<sos> man in blue shirt is walking along side of wooden fence <eos>',
#  '<sos> skier flies through air with snowboard in background <eos>',
#  '<sos> dog is running through woods <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> girl in pink swimsuit in pool wearing waterwings <eos>',
#  '<sos> black dog is running through water <eos>',
#  '<sos> man in red helmet is riding his bike on dirt road <eos>',
#  '<sos> black dog is standing on its hind legs while holding up some red tube <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> black dog carries bird in its mouth <eos>',
#  '<sos> bicyclist is performing trick over heavily that is advertising on ground <eos>',
#  '<sos> man in black and white helmet is riding bike down paved road <eos>',
#  '<sos> brown dog is laying on blue blanket <eos>',
#  '<sos> man in black shirt is looking down at person in front of transparent awning <eos>',
#  '<sos> climber is climbing rock face whilst attached to safety harness in front of building <eos>',
#  '<sos> dog is running through field <eos>',
#  '<sos> girl in black shirt is looking through air to catch green ball <eos>',
#  '<sos> man in red helmet riding down hill on hill <eos>',
#  '<sos> black and brown dog is running on sand <eos>',
#  '<sos> boy in white shirt is jumping over hurdle <eos>',
#  '<sos> boy is climbing artificial from metal tunnel <eos>',
#  '<sos> boy in blue shirt with blue shirt is on his head in front of some trees <eos>',
#  '<sos> man in red uniform is riding red motorcycle while another man in red jacket is on top of mountain <eos>',
#  '<sos> man in yellow jacket is snowboarding over cliff <eos>',
#  '<sos> man in blue shirt is sitting in front of brick wall <eos>',
#  '<sos> man in blue shirt is standing next to man in blue shirt <eos>',
#  '<sos> girl in pink dress is running through grass <eos>',
#  '<sos> man in yellow shirt is airborne <eos>',
#  '<sos> man in red shirt is airborne <eos>',
#  '<sos> man is sitting in chair with umbrella in front of wooden door <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> boy in red shirt is airborne on skateboard in front of wall <eos>',
#  '<sos> couple of people are standing in front of building <eos>',
#  '<sos> female in blue shorts is jumping in air while another man watches <eos>',
#  '<sos> cyclist is riding bike on track <eos>',
#  '<sos> boy in green shirt is doing skateboard trick in ramp <eos>',
#  '<sos> man in yellow kayak is walking through deep water <eos>',
#  '<sos> boy in red shirt and jeans is walking along side of road in front of white building <eos>',
#  '<sos> boy in swimsuit stands in pool <eos>',
#  '<sos> brown dog is running through field <eos>',
#  '<sos> skier flies through air <eos>',
#  '<sos> boy in black shirt is standing on top of cliff in front of wall <eos>',
#  '<sos> man in boat on lake <eos>',
#  '<sos> group of people stand in front of brick wall <eos>',
#  '<sos> black and brown dog is playing with red ball in its mouth <eos>',
#  '<sos> football player is about to make layup <eos>',
#  '<sos> baby in red shirt is holding onto handlebars device in front of her face <eos>',
#  '<sos> boy in striped shirt straddles on train <eos>',
#  '<sos> black dog is running on ground by two brown dogs <eos>',
#  '<sos> man in black hat and hat talks to woman in black and white shirt <eos>',
#  '<sos> brown dog is laying on his hind legs on carpeting in front of chair <eos>',
#  '<sos> man is snowboarding in water <eos>',
#  '<sos> group of people are standing on beach with sun in background <eos>',
#  '<sos> black and brown dog is running in grass <eos>',
#  '<sos> baby in red shirt is holding onto handlebars in front of boys <eos>',
#  '<sos> boy in blue shirt is playing with blue doll <eos>',
#  '<sos> girl in black dress is smiling with woman in background <eos>',
#  '<sos> child in red jacket is climbing on rock wall <eos>',
#  '<sos> dog is staring at another dog who is wearing blue collar <eos>',
#  '<sos> skier flies through air <eos>',
#  '<sos> boy in blue shirt is rock climbing <eos>',
#  '<sos> group of people are standing in front of brick building <eos>',
#  '<sos> group of children playing in field <eos>',
#  '<sos> black and white dog is swimming through water <eos>',
#  '<sos> baby is sitting on bed next to man in blue shirt <eos>',
#  '<sos> boy in red shirt is jumping on skateboard in front of crowd <eos>',
#  '<sos> boy in red shirt is playing with blue ball <eos>',
#  '<sos> group of men in camouflage pants and shirts standing in front of brick wall <eos>',
#  '<sos> man and woman are sitting on bench <eos>',
#  '<sos> girl in black dress is standing next to man in black and white checkered <eos>',
#  '<sos> boy in red shirt plays with basketball <eos>',
#  '<sos> boy in red shirt is running in grass <eos>',
#  '<sos> three people are standing on beach with two people in background <eos>',
#  '<sos> dog is jumping over barrier at competition <eos>',
#  '<sos> black dog is running through grass <eos>',
#  '<sos> boy is standing on top of steps in front of building <eos>',
#  '<sos> boy in red shirt is jumping into air while another boy watches <eos>',
#  '<sos> boy in blue shirt is looking down at somthing woman in blue shirt <eos>',
#  '<sos> man is riding bicycle on dirt track <eos>',
#  '<sos> man in black jacket is standing next to man in black jacket and red cap <eos>',
#  '<sos> man in black jacket is sitting on bench in front of house <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> group of children in village stand outside <eos>',
#  '<sos> couple standing outside of building <eos>',
#  '<sos> boy in black shirt is throwing ball to get rope <eos>',
#  '<sos> group of people walking down street <eos>',
#  '<sos> group of men in camouflage pants are standing in front of reception desk <eos>',
#  '<sos> boy in blue shirt is running in field of grass <eos>',
#  '<sos> dog is jumping up to another dog who is wearing blue shirt <eos>',
#  '<sos> boy in red jacket is jumping up on snowy mountain <eos>',
#  '<sos> man in red shirt is airborne while another man in striped shirt is sitting in front of some steps <eos>',
#  '<sos> dog is running through grass <eos>',
#  '<sos> man in black and white shirt is sitting on bench with his arms crossed <eos>',
#  '<sos> man in blue shirt is looking at burning incense sticks <eos>',
#  '<sos> brown dog is running on sand <eos>',
#  '<sos> boy in green shirt is riding his bike on paved road <eos>',
#  '<sos> boy in red shirt plays with toy in pool <eos>',
#  '<sos> boy in red shirt is running on grass <eos>',
#  '<sos> boy wears mr potato head features <eos>',
#  '<sos> boy in wetsuit is surfing <eos>',
#  '<sos> boy in red shirt is jumping in air <eos>',
#  '<sos> people in red shirt is standing on field of flowers <eos>',
#  '<sos> man in yellow boat paddling down rough waters <eos>',
#  '<sos> man in red jacket is riding on bike <eos>',
#  '<sos> child is walking on beach with sun in background <eos>',
#  '<sos> group of people stand in front of brick wall <eos>',
#  '<sos> girl in black shirt is sitting on bench in front of wooden fence <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> boy in red shirt is jumping on his skateboard in front of building <eos>',
#  '<sos> boy in red shirt is jumping into air with his arms out in air <eos>',
#  '<sos> boy is pushing another boy on his back hand while another boy watches <eos>',
#  '<sos> boy in blue shirt is being splashed by two people in front of building <eos>',
#  '<sos> girl in white dress is standing next to man in black shirt <eos>',
#  '<sos> brown dog is running on beach <eos>',
#  '<sos> climber is climbing rock face above mattress that is lying on ground below below <eos>',
#  '<sos> brown dog is splashing in water <eos>',
#  '<sos> man in yellow boat paddling down rough water <eos>',
#  '<sos> black dog is running through field of tall flowers <eos>',
#  '<sos> black dog is running through grass <eos>',
#  '<sos> biker speeds in woods <eos>',
#  '<sos> man in black wetsuit is surfing <eos>',
#  '<sos> man in yellow boat paddling down water <eos>',
#  '<sos> man in sunglasses and hat talks with his arms crossed <eos>',
#  '<sos> boy in green shirt is jumping in air while snowboarding <eos>',
#  '<sos> boy in red shirt and blue jeans is playing with ball in front of house <eos>',
#  '<sos> climber is scaling mountain cliff to ground in front of mountain <eos>',
#  '<sos> man in white shirt and tie hat talks to cross street with crowd in background <eos>',
#  '<sos> dog is running through snow <eos>',
#  '<sos> group of people are playing together in kitchen <eos>',
#  '<sos> black and brown dog is running on dirt path <eos>',
#  '<sos> boy in green shirt is sitting on bench in front of wooden barn <eos>',
#  '<sos> black dog is jumping up to catch green object <eos>',
#  '<sos> boy in brown jacket is running through snow <eos>',
#  '<sos> boy in red shirt is jumping in air while another man watches <eos>',
#  '<sos> black dog is jumping into swimming pool <eos>',
#  '<sos> black dog is jumping over hurdle <eos>',
#  '<sos> baby is sitting on bed and looking at camera <eos>',
#  '<sos> man in red shirt is riding skateboard down paved road <eos>',
#  '<sos> girl in white dress is standing on couch with stuffed animals <eos>',
#  '<sos> boy in swimsuit is jumping into pool with water <eos>',
#  '<sos> dog is running through field of dead leaves <eos>',
#  '<sos> couple walking along side of street <eos>',
#  '<sos> man in blue shirt is standing in front of reception desk <eos>',
#  '<sos> boy in green shirt is riding skateboard in public of two people <eos>',
#  '<sos> black dog is running through field <eos>',
#  '<sos> man in black jacket is holding up electronic device in front of building <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> boy in blue shorts is running on grass with his mouth open <eos>',
#  '<sos> man in brown jacket is standing in front of reception desk <eos>',
#  '<sos> girl in pink dress is standing on sidewalk <eos>',
#  '<sos> two asian women in red and white shirts are standing in front of building <eos>',
#  '<sos> black dog is running through snow <eos>',
#  '<sos> basketball player in white uniform is about to kick ball <eos>',
#  '<sos> girl in pink dress is running through green grass <eos>',
#  '<sos> girl in white dress is standing in front of reception desk <eos>',
#  '<sos> dog is running through woods <eos>',
#  '<sos> black and white dog is running through water <eos>',
#  '<sos> man in black shirt is sitting on bench with arms outstretched <eos>',
#  '<sos> boy in red shirt is standing on top of cliff in front of building <eos>',
#  '<sos> girl in pink shirt is running along side of tree <eos>',
#  '<sos> man in black jacket is sitting on bench in front of house <eos>',
#  '<sos> man in black hat is sitting next to florescent green bag in front of glass <eos>',
#  '<sos> dog is running through snow <eos>',
#  '<sos> black dog is jumping over log in water <eos>',
#  '<sos> brown dog is running on beach <eos>',
#  '<sos> basketball player in blue uniform is about to kick ball <eos>',
#  '<sos> baseball player hitting ball <eos>',
#  '<sos> boy in red shirt is running in field of flowers <eos>',
#  '<sos> skier flies through air on snowy day <eos>',
#  '<sos> baseball player in red uniform is running in field during game <eos>',
#  '<sos> girl in pink shirt is splashing in water <eos>',
#  '<sos> brown dog is jumping up at another black dog who is carrying ball <eos>',
#  '<sos> girl in white dress is running on grass <eos>',
#  '<sos> girl in pink dress is climbing up wall <eos>',
#  '<sos> boy in swimsuit is splashing in water <eos>',
#  '<sos> man is doing trick on skateboard <eos>',
#  '<sos> brown dog is running in grass <eos>',
#  '<sos> girl with star painted is smiling <eos>',
#  '<sos> boy in red shirt is standing on skateboard in front of building <eos>',
#  '<sos> girl in pink shirt is running along beach <eos>',
#  '<sos> brown dog is standing on beach with something in its mouth <eos>',
#  '<sos> brown dog is chewing on bone <eos>',
#  '<sos> couple sits atop tree on wall and looking down <eos>',
#  '<sos> group of people ride on bicycle in front of city street <eos>',
#  '<sos> group of people are sitting in room with candles <eos>',
#  '<sos> man in yellow jacket climbs over snow <eos>',
#  '<sos> group of people are playing in water fountain <eos>',
#  '<sos> group of people are standing in front of building with arms crossed <eos>',
#  '<sos> man is doing trick on skateboard <eos>',
#  '<sos> man in black jacket is riding down bike on sidewalk <eos>',
#  '<sos> boy is jumping over multicolored barrier <eos>',
#  '<sos> child in red shorts is walking along beach with white dog in background <eos>',
#  '<sos> bird flies through air <eos>',
#  '<sos> child in green shirt is looking at camera in front of another man who is wearing blue shirt <eos>',
#  '<sos> man in black shirt is sitting on bench in front of house <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> girl in pink dress is blowing bubbles <eos>',
#  '<sos> man in black jacket is sitting on bench in front of house <eos>',
#  '<sos> bicyclist is performing trick over dirt course <eos>',
#  '<sos> boy in black shirt is standing in front of brick wall <eos>',
#  '<sos> man in black shirt is standing in front of reception desk <eos>',
#  '<sos> boy in black shirt is jumping on skateboard in front of wall <eos>',
#  '<sos> bike rider in air above ramp <eos>',
#  '<sos> man in red coat is walking through snow <eos>',
#  '<sos> girl in black shirt is smiling with woman in her hand <eos>',
#  '<sos> man is snowboarding down hill with his arms crossed <eos>',
#  '<sos> man and woman in winter clothes stand near fireplace and christmas tree <eos>',
#  '<sos> boy in blue shirt is playing with tennis ball in his mouth <eos>',
#  '<sos> two brown dogs are running down dirt path <eos>',
#  '<sos> man in orange shirt is about to kick ball <eos>',
#  '<sos> man in black shirt is standing in front of white building and another man in blue shirt <eos>',
#  '<sos> boy in swimsuit jumping into pool <eos>',
#  '<sos> group of children playing in fountain <eos>',
#  '<sos> group of men play basketball <eos>',
#  '<sos> black and white dog is jumping over hurdle <eos>',
#  '<sos> black and white dog with red bandanna is sitting in chair <eos>',
#  '<sos> boy in red shirt is jumping into air with his arms outstretched in air <eos>',
#  '<sos> dog is jumping over white barrier <eos>',
#  '<sos> brown and white dog is running on grass <eos>',
#  '<sos> girl in pink shirt is sitting on bed next to man in blue shirt <eos>',
#  '<sos> baby in blue shirt is playing with blue doll on wooden floor <eos>',
#  '<sos> man is standing on top of large tree and taking pictures <eos>',
#  '<sos> man in red shirt and tie is standing in front of brick building in front of building <eos>',
#  '<sos> man in black jacket is climbing rock face <eos>',
#  '<sos> boy is eating large camera <eos>',
#  '<sos> boy in black shirt is standing in front of brick wall while another man watches <eos>',
#  '<sos> boy in red shirt is jumping into air with his arms spread wide <eos>',
#  '<sos> man is doing trick on skateboard <eos>',
#  '<sos> girl in black dress with her hair smiling <eos>',
#  '<sos> cyclist is riding on bicycle in front of road <eos>',
#  '<sos> man in black shirt is sitting on bench in front of wooden barn <eos>',
#  '<sos> dog is running through snow <eos>',
#  '<sos> man in blue shirt and blue shirt is splashing in water <eos>',
#  '<sos> boy in swimming pool <eos>',
#  '<sos> brown dog is running on beach <eos>',
#  '<sos> group of people are standing in front of brick wall <eos>',
#  '<sos> man in black jacket is standing next to man in black jacket and black jacket is sitting on sidewalk <eos>',
#  '<sos> brown dog is jumping over hurdle <eos>',
#  '<sos> man in black is sitting on bench in front of building <eos>',
#  '<sos> man in black shirt is standing in front of reception desk <eos>',
#  '<sos> boy in blue shirt is riding on roller coaster <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> man in blue shirt is looking at camera while another man watches <eos>',
#  '<sos> brown dog is chewing on bone <eos>',
#  '<sos> brown and white dog is standing on sand at beach <eos>',
#  '<sos> black and white dog is running in grass <eos>',
#  '<sos> girl in pink dress is blowing bubbles <eos>',
#  '<sos> black and brown dog is running in snow <eos>',
#  '<sos> black dog is swimming through water <eos>',
#  '<sos> people are boating on rock looking at view of water <eos>',
#  '<sos> man in black jacket is sitting on bench in front of building <eos>',
#  '<sos> girl in pink dress is playing with hula hoops <eos>',
#  '<sos> man in blue shirt is jumping into air <eos>',
#  '<sos> girl in white shirt and jeans is standing in front of another man in blue shirt <eos>',
#  '<sos> dog rolls in its mouth <eos>',
#  '<sos> woman in purple dress is holding up proamerica her hand while sitting on bed <eos>',
#  '<sos> man in black shirt is sitting next to modern art with umbrella in front of building <eos>',
#  '<sos> group of men play college football <eos>',
#  '<sos> man in black shirt sitting on bench in front of wooden wall <eos>',
#  '<sos> child in green shirt is sitting on pavement next to fence <eos>',
#  '<sos> two blonde women are wearing red jacket and red tie are smiling on cellphone <eos>',
#  '<sos> man in black wetsuit is surfing <eos>',
#  '<sos> brown dog is standing in front of reception brown dog <eos>',
#  '<sos> black dog is running through water <eos>',
#  '<sos> cyclist is riding bicycle on curved road in front of blue and red building <eos>',
#  '<sos> group of people are standing on beach with two people behind him <eos>',
#  '<sos> man in blue shorts is walking along rock next to waterfall <eos>',
#  '<sos> boy in green shirt is standing on top of steps in front of building <eos>',
#  '<sos> black and white dog is running through snow <eos>',
#  '<sos> boy and girl are playing in field of flowers <eos>',
#  '<sos> black dog in snow <eos>',
#  '<sos> man in black jacket is sitting on rock ledge overlooking water <eos>',
#  '<sos> boy in blue shirt is jumping into air while another boy watches <eos>',
#  '<sos> girl in black dress is sitting on bed <eos>',
#  '<sos> girl in black dress is walking on sidewalk <eos>',
#  '<sos> man in black shirt is standing in front of reception desk <eos>',
#  '<sos> group of girls in pink and black clothing are standing in front of reception desk <eos>',
#  '<sos> man in blue shirt is looking down at large tree <eos>',
#  '<sos> man in black jacket is standing next to man in black jacket and red cap <eos>',
#  '<sos> man in black wetsuit is surfing <eos>',
#  '<sos> bird flies through water <eos>',
#  '<sos> boy is jumping off of water with his arms spread around him <eos>',
#  '<sos> man in black shirt is sitting on bench in front of large window <eos>',
#  '<sos> man in black shirt is looking at camera in front of man in blue shirt <eos>',
#  '<sos> boy in blue shirt is splashing in water <eos>',
#  '<sos> black and white dog is playing with tennis ball <eos>',
#  '<sos> man in black shirt is standing in front of reception desk <eos>',
#  '<sos> boy in red jacket is standing on top of cliff in snow <eos>',
#  '<sos> girl in black dress is sitting on bench next to girl in black jacket <eos>',
#  '<sos> man in black jacket is smiling with his arms crossed <eos>',
#  '<sos> boy in red helmet is riding down path <eos>',
#  '<sos> brown and white dog is jumping up to catch ball <eos>',
#  '<sos> man in black wetsuit is surfing on beach <eos>',
#  '<sos> girl in black dress is standing next to man in black jacket <eos>',
#  '<sos> man in blue shirt is airborne <eos>',
#  '<sos> girl in pink shirt is splashing in water <eos>',
#  '<sos> black and brown dog is running through woods <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> man in black jacket is smiling with woman in black shirt <eos>',
#  '<sos> man in yellow kayak is surfing <eos>',
#  '<sos> group of people ride down rocky hill on dirt trail <eos>',
#  '<sos> dog runs through field <eos>',
#  '<sos> man in black shirt is sitting in front of brick wall <eos>',
#  '<sos> bird flies through water <eos>',
#  '<sos> boy hits ball during game <eos>',
#  '<sos> girl in black dress is smiling with woman in her hand <eos>',
#  '<sos> dog is running through field <eos>',
#  '<sos> group of people are standing in front of mountain <eos>',
#  '<sos> woman in black and white dress is smiling with woman in her hand <eos>',
#  '<sos> group of people are standing in front of brick wall <eos>',
#  '<sos> lone snowboarder is standing on top of cliff overlooking mountain <eos>',
#  '<sos> man in blue shirt is walking through water <eos>',
#  '<sos> man is sitting on boat in water <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> brown dog is jumping over obstacle course <eos>',
#  '<sos> boy in blue shirt is walking along path in woods <eos>',
#  '<sos> man in hat and hat talks with woman in front of her friend <eos>',
#  '<sos> brown dog is running on grass <eos>',
#  '<sos> brown dog is running on beach <eos>',
#  '<sos> man in black jacket is riding on slope <eos>',
#  '<sos> man in black jacket is sitting on bench in front of house <eos>',
#  '<sos> boy in red shirt is jumping on skateboard in front of wall <eos>',
#  '<sos> football player in red is challenging player in white uniform <eos>',
#  '<sos> couple of people sitting on dock at sunset <eos>',
#  '<sos> black and white dog is sitting on bench with several people walking behind them <eos>',
#  '<sos> baby in blue shirt is holding onto handlebars <eos>',
#  '<sos> dog is running on grass <eos>',
#  '<sos> man in blue shirt is operating fiery furnace <eos>',
#  '<sos> group of men are standing in front of building <eos>',
#  '<sos> dog is running through woods <eos>',
#  '<sos> man is sitting on bench in front of window <eos>',
#  '<sos> boy in red shirt is airborne on skateboard in front of wall <eos>',
#  '<sos> black dog is jumping up to catch red toy <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> boy in swimsuit is jumping into pool <eos>',
#  '<sos> man in red helmet is riding down mountain with bike on trail <eos>',
#  '<sos> brown and white dog is walking on beach with stick in its mouth <eos>',
#  '<sos> man in black helmet is riding bike through forest <eos>',
#  '<sos> boy in blue shirt is jumping into pool <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> man in black shirt is sitting on bench with his arms crossed <eos>',
#  '<sos> group of people are sitting on bench in front of wooden seats <eos>',
#  '<sos> boy in black shirt is airborne with his skateboard in air while standing on it <eos>',
#  '<sos> boy in red shirt is splashing in water <eos>',
#  '<sos> man in orange shirt and blue helmet is riding his bike in woods <eos>',
#  '<sos> man in black shirt is looking at camera in front of man in blue shirt <eos>',
#  '<sos> black and white dog is jumping over hurdle <eos>',
#  '<sos> boy in red shorts is standing on top of cliff <eos>',
#  '<sos> brown and white dog is jumping in air <eos>',
#  '<sos> man in black shirt is sitting on bench in front of house <eos>',
#  '<sos> man in black jacket is smiling while woman in black jacket <eos>',
#  '<sos> man in black shirt is sitting on rock next to man in blue shirt <eos>',
#  '<sos> girl in black dress is sitting on bench with umbrella in front of her arms <eos>',
#  '<sos> man in black hat and sunglasses is smiling with woman in blue shirt <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> man in black shirt is climbing rock face <eos>',
#  '<sos> brown dog is chewing on bone with stuffed animal <eos>',
#  '<sos> group of men play soccer <eos>',
#  '<sos> black dog is running through grass <eos>',
#  '<sos> baseball player hitting ball <eos>',
#  '<sos> group of people are standing in front of lake <eos>',
#  '<sos> group of men play hockey on street <eos>',
#  '<sos> black and white dog is jumping over hurdle <eos>',
#  '<sos> boy and girl are playing in field of flowers <eos>',
#  '<sos> boy in red shirt is jumping in air while another man watches <eos>',
#  '<sos> brown dog is running in sand <eos>',
#  '<sos> girl in black shirt is smiling with woman in her hand <eos>',
#  '<sos> bird flies through water <eos>',
#  '<sos> man in white shirt is holding onto handlebars to put man in black shirt <eos>',
#  '<sos> man in black shirt is sitting in gym <eos>',
#  '<sos> boy is pushing another boy in blue shirt with his arms crossed <eos>',
#  '<sos> brown dog is running through field <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> man in black jacket is standing in front of reception desk <eos>',
#  '<sos> baseball player is about to hit ball while another man watches <eos>',
#  '<sos> girl in black dress is standing next to man in black jacket <eos>',
#  '<sos> boy in blue shirt is playing with soccer ball <eos>',
#  '<sos> hiker is standing on top of cliff overlooking mountains <eos>',
#  '<sos> group of people are sitting in front of wooden wall <eos>',
#  '<sos> girl in pink dress is walking through puddle <eos>',
#  '<sos> boy in shorts is standing on top of cliff <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> boy in red shirt is jumping on skateboard in front of wall with arms crossed <eos>',
#  '<sos> group of people are standing in front of crowd <eos>',
#  '<sos> black dog is swimming through water <eos>',
#  '<sos> group of people are standing in front of fence <eos>',
#  '<sos> woman in sunglasses and hat talks with woman in black shirt <eos>',
#  '<sos> basketball player in blue uniform is about to make shot <eos>',
#  '<sos> boy in black shirt is running on sand <eos>',
#  '<sos> man in black jacket is sitting on bench in front of building <eos>',
#  '<sos> boy in blue shirt is jumping into air while another man watches <eos>',
#  '<sos> boy in red shirt is riding skateboard down concrete wall <eos>',
#  '<sos> man in black is sitting on bench in front of crowd <eos>',
#  '<sos> man in black jacket is smiling with woman in black and white shirt <eos>',
#  '<sos> dog is running through field <eos>',
#  '<sos> black dog is looking at tabby dog who is sitting on blanket <eos>',
#  '<sos> downhill skier in red jacket is snowboarding <eos>',
#  '<sos> girl in pink shirt is walking along side of fence <eos>',
#  '<sos> man in red shirt and white shorts is standing in front of brick building with another man in blue shirt <eos>',
#  '<sos> group of people stand in front of large bush and looks at it <eos>',
#  '<sos> man in black is walking along white fence whilst two people in background <eos>',
#  '<sos> brown dog is running through water <eos>',
#  '<sos> black dog is running through grass <eos>',
#  '<sos> bicycler is standing on sidewalk with two people behind him <eos>',
#  '<sos> boy in blue shirt is blowing bubbles with his arms crossed <eos>',
#  '<sos> man in red coat is standing in front of snow on lake <eos>',
#  '<sos> man in black is riding bicycle in street <eos>',
#  '<sos> boy in orange shirt is standing in front of brick wall <eos>',
#  '<sos> boy plays on swing <eos>',
#  '<sos> man in snow on bicycle rides on snow <eos>',
#  '<sos> boy in green shirt is doing skateboard trick in city <eos>',
#  '<sos> boy in green shirt is playing with tennis ball in front of large pool <eos>',
#  '<sos> man in yellow boat paddling down rough waters <eos>',
#  '<sos> black dog is running through field of water <eos>',
#  '<sos> girl in pink dress is walking on sidewalk <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> man in white shirt is sitting on bench with his feet up <eos>',
#  '<sos> boy in blue shirt is splashing in water <eos>',
#  '<sos> group of men play in field <eos>',
#  '<sos> brown dog is jumping up to catch red ball <eos>',
#  '<sos> boy in green shirt is standing in front of brick wall <eos>',
#  '<sos> man is standing on top of mountain gazing <eos>',
#  '<sos> black dog is swimming through water <eos>',
#  '<sos> black and brown dog is jumping over hurdle <eos>',
#  '<sos> man in black shirt is looking at camera in front of man in blue shirt <eos>',
#  '<sos> man in red uniform is riding on racetrack <eos>',
#  '<sos> girl in dress sits on sidewalk with man in black shirt <eos>',
#  '<sos> brown dog is jumping up to catch red toy <eos>',
#  '<sos> black and brown dog is swimming in pool <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> man and woman are sitting on bench with their arms crossed <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> football player pauses to tackle another <eos>',
#  '<sos> man in black shirt is sitting in front of glass wall <eos>',
#  '<sos> boy in blue shirt is splashing in water <eos>',
#  '<sos> child in pool with blue shirt is in air <eos>',
#  '<sos> girl in bikini is jumping into water <eos>',
#  '<sos> boy in blue shirt is running through field <eos>',
#  '<sos> man in white shirt and brown shorts is standing on grass beside something in front of another <eos>',
#  '<sos> man and woman in front of tables walking <eos>',
#  '<sos> girl in swimsuit is splashing in water <eos>',
#  '<sos> dog is running through some sand <eos>',
#  '<sos> man in red jacket is standing on top of mountain gazing at sunset <eos>',
#  '<sos> group of people in red shirts are standing in front of building <eos>',
#  '<sos> boy in red and white soccer ball with soccer ball in field of ball <eos>',
#  '<sos> man in red shirt is airborne on skateboard in front of snow <eos>',
#  '<sos> group of girls are playing in fountain <eos>',
#  '<sos> black and white dog is jumping up to catch white ball <eos>',
#  '<sos> group of people are standing in front of large colorful building <eos>',
#  '<sos> man in yellow boat paddling down rough waters <eos>',
#  '<sos> man in blue shirt is sitting on bench with blue blanket <eos>',
#  '<sos> climber is scaling mountain <eos>',
#  '<sos> climber is scaling mountain cliff <eos>',
#  '<sos> group of people are walking in desert <eos>',
#  '<sos> group of people are riding on roller coaster <eos>',
#  '<sos> man in black shirt is looking at pad in black room <eos>',
#  '<sos> black dog carries toy in its mouth <eos>',
#  '<sos> brown dog is swimming in air by water <eos>',
#  '<sos> two girls in skirts walking on sidewalk <eos>',
#  '<sos> group of men play hockey on field <eos>',
#  '<sos> cyclist is riding bike through air <eos>',
#  '<sos> group of people are standing on desert with two people standing around him <eos>',
#  '<sos> boy in swimsuit is standing in front of water on beach <eos>',
#  '<sos> man in black shirt is sitting on bench with his arms crossed <eos>',
#  '<sos> man in black shirt is standing in front of reception desk <eos>',
#  '<sos> boy dives into pool <eos>',
#  '<sos> boy in blue shirt is jumping into air by man in blue shirt <eos>',
#  '<sos> man in red jacket is standing in front of skyscraper <eos>',
#  '<sos> black and white dog is running in field <eos>',
#  '<sos> girl in white shirt is holding onto handles that says her hand <eos>',
#  '<sos> black dog is jumping into water from water <eos>',
#  '<sos> man in red shirt climbs rock climbing <eos>',
#  '<sos> boy in blue wetsuit is surfing <eos>',
#  '<sos> black dog is in water <eos>',
#  '<sos> dog is running through field <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> boy in red shirt is standing on top of cliff in front of building <eos>',
#  '<sos> couple of people walking through water <eos>',
#  '<sos> man and woman in black shirt sitting on bench <eos>',
#  '<sos> boy in blue shirt is splashing in water <eos>',
#  '<sos> brown dog is jumping up to catch green ball <eos>',
#  '<sos> group of people are walking in front of audience in front of white building <eos>',
#  '<sos> black dog is running on beach <eos>',
#  '<sos> boy is standing on top of water fountain <eos>',
#  '<sos> boy in green shirt is riding down concrete path <eos>',
#  '<sos> brown dog is running on beach <eos>',
#  '<sos> man in white shirt and black dog is running on grass <eos>',
#  '<sos> brown and black dog is running with brown dog in grass <eos>',
#  '<sos> white dog is running through snow <eos>',
#  '<sos> man in black jacket is standing by window of coffee shop <eos>',
#  '<sos> man in black shirt is sitting in front of brick wall <eos>',
#  '<sos> man is doing trick on skateboard <eos>',
#  '<sos> boy is doing skateboard trick in air while being videotaped <eos>',
#  '<sos> man in black jacket is sitting on rock next to big green bag <eos>',
#  '<sos> boy doing trick on skateboard <eos>',
#  '<sos> man in blue shirt is looking down at bottom of water <eos>',
#  '<sos> boy in blue shirt is walking along path in front of large building <eos>',
#  '<sos> crane lifts into air above water <eos>',
#  '<sos> group of people are standing in front of frozen waterfall <eos>',
#  '<sos> black and white dog is jumping up to catch green ball <eos>',
#  '<sos> man in black jacket is standing in front of reception desk <eos>',
#  '<sos> man in black and white hat is sitting next to woman in blue shirt <eos>',
#  '<sos> girl in pink dress is running on grass <eos>',
#  '<sos> man in red uniform is riding unicycle in race <eos>',
#  '<sos> boy in black shirt is grabbing basketball player in white uniform <eos>',
#  '<sos> black and white dog is standing next to man in black shirt <eos>',
#  '<sos> man in black jacket is holding up electronic device while wearing mask <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> man in checked shirt is holding onto handlebars to his mouth while sitting in water <eos>',
#  '<sos> man in red shirt is rock climbing <eos>',
#  '<sos> man in yellow kayak is surfing <eos>',
#  '<sos> dog is running through sand <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> black dog is swimming in water <eos>',
#  '<sos> girl in purple dress is running on grass <eos>',
#  '<sos> bird flies over water <eos>',
#  '<sos> girl in black dress is smiling while woman in headscarf looks on <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> boy in red shirt is jumping up on rock face while another man in white shirt <eos>',
#  '<sos> black and white dog is running with its mouth open <eos>',
#  '<sos> black and white dog is jumping over log in snow <eos>',
#  '<sos> man in white shirt is jumping into air while another man watches <eos>',
#  '<sos> child in red coat plays with red toy <eos>',
#  '<sos> black dog is running through grass <eos>',
#  '<sos> climber scales rock face <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> man in red jacket and hat is walking through snow <eos>',
#  '<sos> man in black shirt is looking at pad of people in front of wooden seats <eos>',
#  '<sos> black dog is running through some sand <eos>',
#  '<sos> man in red coat is snowboarding down slope <eos>',
#  '<sos> man in black jacket is sitting on bench in front of house <eos>',
#  '<sos> man and woman are riding bikes on street <eos>',
#  '<sos> dog is swimming in pool <eos>',
#  '<sos> man in red jacket is standing next to man in black jacket is looking at camera in front of tree <eos>',
#  '<sos> black and white dog with brown dog in snow <eos>',
#  '<sos> boy in black shirt is standing in front of brick wall while another man watches <eos>',
#  '<sos> boy in red shirt is walking along sidewalk in city street <eos>',
#  '<sos> girl with star painted is smiling while woman in blue shirt looks on <eos>',
#  '<sos> man in red coat is snowboarding in snow <eos>',
#  '<sos> brown dog is running through field of tall flowers <eos>',
#  '<sos> dog is running along beach by trees <eos>',
#  '<sos> brown dog is running on beach <eos>',
#  '<sos> black dog is running on grass beside white dog <eos>',
#  '<sos> man in black jacket is sitting in chair <eos>',
#  '<sos> brown dog is running in field <eos>',
#  '<sos> child in red jacket is sitting on bed <eos>',
#  '<sos> black dog is running through snow <eos>',
#  '<sos> dog running through field <eos>',
#  '<sos> man in white shirt and black pants is standing next to man in black jacket and red cap <eos>',
#  '<sos> boy in black shirt is standing in front of brick wall <eos>',
#  '<sos> boy in red shirt is holding onto handlebars in front of water <eos>',
#  '<sos> man in black helmet is riding dirt bike in dirt track <eos>',
# ...
#  '<sos> dog is running through sand <eos>',
#  '<sos> girl in pink shirt is blowing bubbles with her arms crossed <eos>',
#  '<sos> boy in swimsuit jumping into pool <eos>',
#  '<sos> brown dog is running on beach <eos>',
#  '<sos> boy in red shirt is rock climbing <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> group of men in red shirts are playing in sparsely <eos>',
#  '<sos> black dog is jumping over log in woods <eos>',
#  '<sos> man in black jacket is standing in front of reception desk <eos>',
#  '<sos> dog is jumping over barrier with yellow ball in background <eos>',
#  '<sos> man in black jacket is standing next to man in black jacket and black jacket <eos>',
#  '<sos> girl in pink shirt is running through field of flowers <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> man and woman are standing in front of building <eos>',
#  '<sos> boy in green shirt is standing in front of brick wall <eos>',
#  '<sos> man in black jacket is walking along sidewalk of road <eos>',
#  '<sos> brown dog is jumping up to catch ball <eos>',
#  '<sos> boy in blue shirt is jumping through air <eos>',
#  '<sos> man in red shirt and tie poses in front of woman in black dress <eos>',
#  '<sos> man in red coat is riding down bike <eos>',
#  '<sos> girl in pink dress is jumping into pool <eos>',
#  '<sos> girl in red shirt is sitting on bench in front of blue wall <eos>',
#  '<sos> man is standing on beach with big black dog is standing in front of water <eos>',
#  '<sos> man in blue shirt is about to hit tennis ball <eos>',
#  '<sos> group of people are playing in pile of unspooled toilet paper <eos>',
#  '<sos> group of people are standing on rock in front of waterfall <eos>',
#  '<sos> boy in red shirt is running on grass with two legs in background <eos>',
#  '<sos> boy in blue shirt is splashing in water <eos>',
#  '<sos> brown and black dog is playing with ball in its mouth <eos>',
#  '<sos> climber in red shirt is scaling rock face whilst being watched by another man in blue shirt <eos>',
#  '<sos> black dog is running through snow <eos>',
#  '<sos> boy is jumping on skateboard in front of wall <eos>',
#  '<sos> man in dooorway of bus bus <eos>',
#  '<sos> man in black jacket is smiling with his arms crossed <eos>',
#  '<sos> brown dog is chewing on bone <eos>',
#  '<sos> dog is running through field <eos>',
#  '<sos> brown and white dog is running on grass <eos>',
#  '<sos> dog is running through snow <eos>',
#  '<sos> man in black shirt is sitting in front of brick wall <eos>',
#  '<sos> little boy plays with bubbles <eos>',
#  '<sos> boy in red shirt runs through field <eos>',
#  '<sos> brown dog is chewing on bone with its mouth open <eos>',
#  '<sos> child in green jacket is sitting on bed next to man in blue shirt <eos>',
#  '<sos> hockey player in red uniform is being tackled by player in white <eos>',
#  '<sos> boy in red shirt is running on pavement <eos>',
#  '<sos> brown dog is running though sand <eos>',
#  '<sos> man in red shirt and black pants is walking through water <eos>',
#  '<sos> baby is sitting in chair next to girl in blue shirt <eos>',
#  '<sos> girl in blue shirt is riding on green swing in front of water <eos>',
#  '<sos> boy is doing skateboard trick on skateboard ramp <eos>',
#  '<sos> man in black shirt is standing in front of reception desk <eos>',
#  '<sos> group of people are standing in front of building in front of house <eos>',
#  '<sos> boy in red shirt is jumping into air with his arms outstretched <eos>',
#  '<sos> brown and white dog is playing with red toy <eos>',
#  '<sos> child in red jacket is walking on beach with several people in background <eos>',
#  '<sos> brown and white dog is playing with red toy <eos>',
#  '<sos> girl in pink bikini and orange shirt is jumping into water <eos>',
#  '<sos> group of children playing soccer in field <eos>',
#  '<sos> girl in purple dress is smiling while woman in headscarf looks at camera <eos>',
#  '<sos> black and white dog is running through woods <eos>',
#  '<sos> black and brown dog is running through snow <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> brown dog is playing with ball in grass <eos>',
#  '<sos> black dog is running through grass <eos>',
#  '<sos> man in black hat reaches for picture <eos>',
#  '<sos> man in blue shirt is holding up electronic device while another man in blue shirt <eos>',
#  '<sos> boy in black shirt is smiling with his arms crossed <eos>',
#  '<sos> girl in bikini and sneakers is standing in water <eos>',
#  '<sos> boy in red shirt and blue shirt is playing with ball in front of brick wall <eos>',
#  '<sos> girl in pink shirt is sitting on sidewalk <eos>',
#  '<sos> dog is running through snow <eos>',
#  '<sos> man in red shirt is sitting in front of computer <eos>',
#  '<sos> boy in green shirt is sitting on bench in front of blue wall <eos>',
#  '<sos> dog is running through field <eos>',
#  '<sos> group of people in red shirts are standing on sidewalk <eos>',
#  '<sos> boy in red shirt is walking along path in woods <eos>',
#  '<sos> baby in white dress is holding up proamerica <eos>',
#  '<sos> man in black shirt is airborne <eos>',
#  '<sos> brown dog is running through field <eos>',
#  '<sos> girl in black bikini is walking on beach with blue sky in background <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> football player in red uniform is tackling another player in white uniform <eos>',
#  '<sos> hockey player in red is challenging player in white uniform <eos>',
#  '<sos> bicyclist is performing trick on dirt trail <eos>',
#  '<sos> man in wetsuit is surfing <eos>',
#  '<sos> boy in red shirt plays with arms crossed <eos>',
#  '<sos> man in black jacket is smiling with his arms crossed <eos>',
#  '<sos> man in black shirt is sitting on bench with blue blanket covering his face <eos>',
#  '<sos> boy in blue shirt is jumping into air <eos>',
#  '<sos> man in black jacket is holding cup in front of another man who is wearing blue shirt <eos>',
#  '<sos> man in black wetsuit is riding his bike on sidewalk <eos>',
#  '<sos> group of men play soccer <eos>',
#  '<sos> boy in red shirt is standing in front of brick wall while another man watches <eos>',
#  '<sos> three children are playing soccer in field <eos>',
#  '<sos> group of people are playing in water <eos>',
#  '<sos> man in white shirt and blue cap is playing with brown dog in grass <eos>',
#  '<sos> brown dog is running through field <eos>',
#  '<sos> man in red shirt is walking through large city street <eos>',
#  '<sos> man in yellow coat is riding down green motorcycle <eos>',
#  '<sos> boy in black shirt is jumping up to catch green ball <eos>',
#  '<sos> black and white dog is running through water <eos>',
#  '<sos> man in black shirt is sitting on bench with arms folded <eos>',
#  '<sos> man in black shirt is sitting on rock next to water <eos>',
#  '<sos> girl in pink dress is splashing in water <eos>',
#  '<sos> man in black shirt is sitting in front of brick wall <eos>',
#  '<sos> man in red jacket and hat holding baby with red purse <eos>',
#  '<sos> girl in purple dress is smiling while holding hands is standing in front of her friend <eos>',
#  '<sos> brown dog is running on grass <eos>',
#  '<sos> girl in pink shirt is running through water <eos>',
#  '<sos> car is airborne with fire in background <eos>',
#  '<sos> people in front of crowd in background <eos>',
#  '<sos> group of people are standing in front of colorful display <eos>',
#  '<sos> boy in blue shirt is running along beach <eos>',
#  '<sos> man in black jacket is standing next to man in black shirt <eos>',
#  '<sos> man in red shirt and jeans stands in front of large fountain <eos>',
#  '<sos> black dog is running through snow <eos>',
#  '<sos> brown dog is jumping over fence <eos>',
#  '<sos> brown dog is running through water <eos>',
#  '<sos> man in white shirt is jumping into swimming pool <eos>',
#  '<sos> black dog is running on grass <eos>',
#  '<sos> group of dogs run through snow <eos>',
#  '<sos> boy is jumping off his skateboard <eos>',
#  '<sos> boy in green shirt is riding his bike on paved road <eos>',
#  '<sos> man is riding atv over mountain <eos>',
#  '<sos> boy in blue shirt is playing with metal ladle in park <eos>',
#  '<sos> boy hits ball with bat <eos>',
#  '<sos> man in white shirt and jeans sits on cellphone by man in black jacket <eos>',
#  '<sos> black dog is swimming through water <eos>',
#  '<sos> boy in blue shirt is jumping into pool <eos>',
#  '<sos> man and woman are sitting on bench in front of water <eos>',
#  '<sos> boy in red jacket is riding down leaf strewn path <eos>',
#  '<sos> hockey player in red uniform is being tackled by player in white uniform <eos>',
#  '<sos> brown and white dog is jumping up to catch red ball <eos>',
#  '<sos> man in black jacket is standing in front of reception desk <eos>',
#  '<sos> man and woman are sitting on bench near water <eos>',
#  '<sos> boy in blue shirt is playing with tennis ball <eos>',
#  '<sos> boy in red shirt and jeans is standing in front of large building <eos>',
#  '<sos> bare chested man is smiling whilst woman in blue shirt <eos>',
#  '<sos> man in orange shirt and hat is standing in front of brick wall <eos>',
#  '<sos> black dog and brown dog is looking at cord it dog <eos>',
#  '<sos> group of people in red racing on dirt road <eos>',
#  '<sos> baby in blue shirt is playing with legos <eos>',
#  '<sos> black and white dog is jumping up to catch green ball <eos>',
#  '<sos> man in yellow boat is paddling through water <eos>',
#  '<sos> boy in red jacket is riding bike down paved road <eos>',
#  '<sos> girl in black dress is walking on sidewalk <eos>',
#  '<sos> brown dog is jumping in air while balancing gold on its mouth <eos>',
#  '<sos> woman in black and white dress is standing next to man in black shirt <eos>',
#  '<sos> black dog is running through water <eos>',
#  '<sos> boy in red jacket is standing on top of cliff in snow <eos>',
#  '<sos> man in black jacket is standing next to man in black jacket and red cap <eos>',
#  '<sos> brown dog is jumping up to catch white dog <eos>',
#  '<sos> group of girls are playing in sparsely at concert <eos>',
#  '<sos> group of people are sitting on platform at outdoor market <eos>',
#  '<sos> boy is doing skateboard trick in front of building <eos>',
#  '<sos> white dog fetches water off of water with stick in its mouth <eos>',
#  '<sos> boy in red shirt is running through field of tall flowers <eos>',
#  '<sos> boy is pushing another boy in air on his bike <eos>',
#  '<sos> female tennis player wearing orange shirt and blue shirt is running in field <eos>',
#  '<sos> man and woman in black shirt sitting on bench <eos>',
#  '<sos> black and white dog is jumping up to catch white dog <eos>',
#  '<sos> group of people are walking in front of bridge <eos>',
#  '<sos> dog is running through field <eos>',
#  '<sos> boy is swimming underwater in pool <eos>',
#  '<sos> black and white dog is running on sand <eos>',
#  '<sos> group of people are playing in water fountain <eos>',
#  '<sos> black and white dog is running through field <eos>',
#  '<sos> little dog is running in field of flowers <eos>',
#  '<sos> man in blue shirt is about to hit tennis ball with his arms crossed <eos>',
#  '<sos> girl in purple dress is smiling while holding onto handlebars <eos>',
#  '<sos> black dog is jumping up at another dog who is carrying ball <eos>',
#  '<sos> man in black jacket is sitting on rock ledge overlooking water <eos>',
#  '<sos> boy is swimming through water <eos>',
#  '<sos> group of children playing with ball <eos>',
#  '<sos> man in black jacket is standing in front of reception desk <eos>',
#  '<sos> blue boat with yellow canopy is floating in yellow kayak <eos>',
#  '<sos> girl in pink shirt is running along side of tree while another girl watches <eos>',
#  '<sos> woman in black dress is sitting on bench next to her groom <eos>',
#  '<sos> man in red helmet is riding bike down paved road <eos>',
#  '<sos> bird flies through water <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> man in black shirt is standing in front of reception desk <eos>',
#  '<sos> group of men play in field hockey <eos>',
#  '<sos> boy in blue shirt is looking at camera while another man watches <eos>',
#  '<sos> basketball player wearing orange jersey is about to hit tennis ball <eos>',
#  '<sos> man in black jacket is standing in front of reception desk <eos>',
#  '<sos> boy in blue shirt is riding on skateboard in skate park <eos>',
#  '<sos> boy in green shirt is doing skateboard trick while another boy watches <eos>',
#  '<sos> man is sitting on rock next to big black dog <eos>',
#  '<sos> man in black shirt is standing in front of brick wall on street <eos>',
#  '<sos> girl in bathing suit plays in water <eos>',
#  '<sos> group of people are walking in front of audience in front of white building <eos>',
#  '<sos> man and woman wearing sunglasses with glasses and black hat is playing guitar <eos>',
#  '<sos> group of men are playing with ball in sand <eos>',
#  '<sos> black dog is running through woods <eos>',
#  '<sos> cyclist is riding bicycle on curved road in front of woods <eos>',
#  '<sos> man is riding atv over hill <eos>',
#  '<sos> man in black jacket is standing on sidewalk with two people in front of crowd <eos>',
#  '<sos> man in black is sitting on bench in front of wooden door <eos>',
#  '<sos> black dog is running through field of tall flowers <eos>',
#  '<sos> man in camouflage pants is standing in front of reception desk <eos>',
#  '<sos> group of men play college while they walk in background <eos>',
#  '<sos> black and white dog is playing with brown dog <eos>',
#  '<sos> group of people are standing in front of building <eos>',
#  '<sos> couple walking along street <eos>',
#  '<sos> boy is jumping into pool <eos>',
#  '<sos> climber is climbing rock face whilst attached to safety harness <eos>',
#  '<sos> group of people are walking on rugged path in front of large brown dog <eos>',
#  '<sos> black and white dog is walking on beach with stick in its mouth <eos>',
#  '<sos> black dog and brown dog are playing with ball in snow <eos>',
#  '<sos> man is airborne with his arms crossed in front of building <eos>',
#  '<sos> brown dog is swimming in water <eos>',
#  '<sos> girl in black dress is standing next to man with black purse and girl in pink shirt <eos>',
#  '<sos> boy in swimming pool wearing goggles gives plays in pool <eos>',
#  '<sos> boy hits tennis ball during game <eos>',
#  '<sos> brown and white dog is running on beach <eos>',
#  '<sos> baby in blue shirt with penguins in front of her face <eos>',
#  '<sos> girl in bathing suit running through water <eos>',
#  '<sos> climber is climbing rock face above mattress that is partly on ground in front of tree <eos>',
#  '<sos> man in black shirt is standing in front of reception desk <eos>',
#  '<sos> girl in pink shirt is splashing in water <eos>',
#  '<sos> man is wakeboarding on surfboard <eos>',
#  '<sos> closeup of man wearing black helmet with sunglasses is wearing blue shirt and blue cap <eos>',
#  '<sos> boy in black shirt is looking through air with something in her mouth <eos>',
#  '<sos> boy in black jacket is sitting on rock next to waterfall <eos>',
#  '<sos> man is climbing up above structure with assistance of pick on it <eos>',
#  '<sos> man in orange shirt and blue shirt with his arms out in air <eos>',
#  '<sos> boy in swimsuit is running through water <eos>',
#  '<sos> dirt biker is aided by another <eos>',
#  '<sos> man in black shirt is about to hit tennis ball in his hand <eos>',
#  '<sos> dog is running through field of tall flowers <eos>',
#  '<sos> brown horse is jumping over hurdle <eos>',
#  '<sos> man riding motorcycle on his motorcycle <eos>',
#  '<sos> brown dog is running on sand <eos>',
#  '<sos> man in black wetsuit is surfing <eos>',
#  '<sos> boy in blue shirt is riding his bike on paved road <eos>',
#  '<sos> black dog is running through water <eos>',
#  '<sos> man is surfing on surfboard <eos>',
#  '<sos> boy is standing on top of cliff in front of building <eos>',
#  '<sos> several kids lies in red coat and blue jeans is running in snow <eos>']

# %%
evalResults(validation_captions, test_captions, lst_labels)
# Out:
# Validation metrics:
#
# BLEU-1 score:  0.52499, BLEU-2 score:  0.30646, BLEU-3 score:  0.19464, BLEU-4 score:  0.12138
# Average METEOR score:  0.37981
#
#
#  Test metrics:
#
# BLEU-1 score:  0.53386, BLEU-2 score:  0.31465, BLEU-3 score:  0.19630, BLEU-4 score:  0.12096
# Average METEOR score:  0.39307

# %% [markdown]
# Loading Subjective image tensor data from the drive

# %%
subject_img_folder = "/content/drive/MyDrive/VR final project/subjective_img_loader.pth"

subjective_img_loader = torch.load(subject_img_folder)

# %% [markdown]
# Testing the model on subjective images

# %%
subjective_captions = outputCaptions(model, subjective_img_loader, VocabObj, MAX_LEN)

# %%
subjective_captions
# Out:
# ['<sos> boy in black shirt is doing skateboard trick <eos>',
#  '<sos> group of people ride bikes on street <eos>',
#  '<sos> crowd of people are standing in front of building <eos>',
#  '<sos> group of people are walking over large white and white dog <eos>',
#  '<sos> dog jumps into air to catch tennis ball <eos>']
